# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import statistics
import seaborn as sns
from pandas_datareader import data

# %% [markdown]
# ### Definimos fecha de inicio, un plazo de 5 anios
# 1 de octubre 2017

# %%
fechaInicio = "2017-10-01"
hoy = datetime.today().strftime('%Y-%m-%d')

# %%
activos = ["AAPL", "MSFT", "AMZN", "GOOGL", "FB", "TSLA", "V"]
activos
# Out:
# ['AAPL', 'MSFT', 'AMZN', 'GOOGL', 'FB', 'TSLA', 'V']

# %%
df = data.DataReader(activos, data_source='yahoo', start=fechaInicio, end=hoy)['Adj Close']
df
# Out:
# Symbols           AAPL        MSFT        AMZN       GOOGL          FB  \
# Date
# 2017-10-02   36.493935   70.107269   47.959499   48.373501         NaN
# 2017-10-03   36.652905   69.778404   47.855000   48.604000         NaN
# 2017-10-04   36.415630   70.182449   48.272499   48.339001         NaN
# 2017-10-05   36.868820   71.385208   49.042500   49.259499         NaN
# 2017-10-06   36.847466   71.413376   49.479000   49.681999         NaN
# ...                ...         ...         ...         ...         ...
# 2022-10-24  149.449997  247.250000  119.820000  102.519997  129.720001
# 2022-10-25  152.339996  250.660004  120.599998  104.480003  137.509995
# 2022-10-26  149.350006  231.320007  115.660004   94.930000  129.820007
# 2022-10-27  144.800003  226.750000  110.959999   92.220001   97.940002
# 2022-10-28  155.740005  235.869995  103.410004   96.290001   99.199997
#
# Symbols           TSLA           V
# Date
# 2017-10-02   22.768667  102.081451
# 2017-10-03   23.209333  102.226662
# 2017-10-04   23.667334  101.955574
# 2017-10-05   23.688667  102.855949
# 2017-10-06   23.792000  103.330360
# ...                ...         ...
# 2022-10-24  211.250000  190.710007
# 2022-10-25  222.419998  194.380005
# 2022-10-26  224.639999  203.330002
# 2022-10-27  225.089996  204.289993
# 2022-10-28  228.520004  209.339996
#
# [1279 rows x 7 columns]

# %%
plt.figure(figsize=(16.2, 5.5))
for i in df.columns.values:
    plt.plot(df[i], label=i)
plt.title('Precio de las Acciones')
plt.xlabel('Fecha', fontsize=18)
plt.ylabel('Precio USD', fontsize=18)
plt.legend(df.columns.values, loc='upper left')
plt.savefig('plotprecios.png', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Calculamos el rendimiento con el periodo anterior

# %%
rendimiento = (df / df.shift(1) -1)
rendimiento
# Out:
# Symbols         AAPL      MSFT      AMZN     GOOGL        FB      TSLA  \
# Date
# 2017-10-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2017-10-03  0.004356 -0.004691 -0.002179  0.004765       NaN  0.019354
# 2017-10-04 -0.006474  0.005790  0.008724 -0.005452       NaN  0.019733
# 2017-10-05  0.012445  0.017138  0.015951  0.019043       NaN  0.000901
# 2017-10-06 -0.000579  0.000395  0.008900  0.008577       NaN  0.004362
# ...              ...       ...       ...       ...       ...       ...
# 2022-10-24  0.014803  0.021188  0.004190  0.013745 -0.002231 -0.014876
# 2022-10-25  0.019338  0.013792  0.006510  0.019118  0.060052  0.052876
# 2022-10-26 -0.019627 -0.077156 -0.040962 -0.091405 -0.055923  0.009981
# 2022-10-27 -0.030465 -0.019756 -0.040636 -0.028547 -0.245571  0.002003
# 2022-10-28  0.075553  0.040220 -0.068042  0.044134  0.012865  0.015238
#
# Symbols            V
# Date
# 2017-10-02       NaN
# 2017-10-03  0.001422
# 2017-10-04 -0.002652
# 2017-10-05  0.008831
# 2017-10-06  0.004612
# ...              ...
# 2022-10-24  0.001786
# 2022-10-25  0.019244
# 2022-10-26  0.046044
# 2022-10-27  0.004721
# 2022-10-28  0.024720
#
# [1279 rows x 7 columns]

# %%
plt.figure(figsize=(16.2, 5.5))
for i in rendimiento.columns.values:
    plt.hist(rendimiento[i], label = i, bins=300)
plt.title('RENDIMIENTOS')
plt.xlabel('Fecha', fontsize=18)
plt.ylabel('Rendimiento', fontsize=18)
plt.legend(rendimiento.columns.values, loc='upper left')
plt.legend(rendimiento.columns.values)
plt.savefig('Rendimientos.png', dpi=150, bbox_inches='tight')

plt.show()

# %% [markdown]
# ### Matriz de covarianzas
#     - Valor que refleja en qué cuantía dos variables aleatorias varían de forma conjunta respecto a sus medias.

# %%
mCovarianzas = rendimiento.cov()
# Escala de colores
cm = sns.light_palette("green", as_cmap=True)
mCovarianzas.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
# #T_f822a_row0_col0{
#             background-color:  #309730;
#             color:  #000000;
#         }#T_f822a_row0_col1,#T_f822a_row2_col0{
#             background-color:  #b4d8b4;
#             color:  #000000;
#         }#T_f822a_row0_col2{
#             background-color:  #c0dec0;
#             color:  #000000;
#         }#T_f822a_row0_col3{
#             background-color:  #cce4cc;
#             color:  #000000;
#         }#T_f822a_row0_col4{
#             background-color:  #cde5cd;
#             color:  #000000;
#         }#T_f822a_row0_col5{
#             background-color:  #d7e9d7;
#             color:  #000000;
#         }#T_f822a_row0_col6{
#             background-color:  #acd4ac;
#             color:  #000000;
#         }#T_f822a_row1_col0{
#             background-color:  #aad3aa;
#             color:  #000000;
#         }#T_f822a_row1_col1{
#             background-color:  #76ba76;
#             color:  #000000;
#         }#T_f822a_row1_col2,#T_f822a_row3_col6{
#             background-color:  #bcdcbc;
#             color:  #000000;
#         }#T_f822a_row1_col3{
#             background-color:  #beddbe;
#             color:  #000000;
#         }#T_f822a_row1_col4{
#             background-color:  #c9e3c9;
#             color:  #000000;
#         }#T_f822a_row1_col5{
#             background-color:  #ddecdd;
#             color:  #000000;
#         }#T_f822a_row1_col6{
#             background-color:  #9dcd9d;
#             color:  #000000;
#         }#T_f822a_row2_col1{
#             background-color:  #b5d9b5;
#             color:  #000000;
#         }#T_f822a_row2_col2{
#             background-color:  #62b062;
#             color:  #000000;
#         }#T_f822a_row2_col3{
#             background-color:  #c4e0c4;
#             color:  #000000;
#         }#T_f822a_row2_col4{
#             background-color:  #a0cea0;
#             color:  #000000;
#         }#T_f822a_row2_col5{
#             background-color:  #d9ead9;
#             color:  #000000;
#         }#T_f822a_row2_col6,#T_f822a_row6_col0,#T_f822a_row6_col1,#T_f822a_row6_col2,#T_f822a_row6_col3,#T_f822a_row6_col4,#T_f822a_row6_col5{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_f822a_row3_col0{
#             background-color:  #c5e0c5;
#             color:  #000000;
#         }#T_f822a_row3_col1{
#             background-color:  #badbba;
#             color:  #000000;
#         }#T_f822a_row3_col2{
#             background-color:  #c2dfc2;
#             color:  #000000;
#         }#T_f822a_row3_col3{
#             background-color:  #8ec58e;
#             color:  #000000;
#         }#T_f822a_row3_col4{
#             background-color:  #b6d9b6;
#             color:  #000000;
#         }#T_f822a_row3_col5{
#             background-color:  #e3efe3;
#             color:  #000000;
#         }#T_f822a_row4_col0,#T_f822a_row4_col1,#T_f822a_row4_col2,#T_f822a_row4_col3,#T_f822a_row4_col4,#T_f822a_row5_col5,#T_f822a_row6_col6{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_f822a_row4_col5{
#             background-color:  #a8d2a8;
#             color:  #000000;
#         }#T_f822a_row4_col6{
#             background-color:  #0c860c;
#             color:  #f1f1f1;
#         }#T_f822a_row5_col0{
#             background-color:  #58ab58;
#             color:  #000000;
#         }#T_f822a_row5_col1{
#             background-color:  #82c082;
#             color:  #000000;
#         }#T_f822a_row5_col2{
#             background-color:  #98ca98;
#             color:  #000000;
#         }#T_f822a_row5_col3{
#             background-color:  #b1d7b1;
#             color:  #000000;
#         }#T_f822a_row5_col4{
#             background-color:  #a9d3a9;
#             color:  #000000;
#         }#T_f822a_row5_col6{
#             background-color:  #6cb56c;
#             color:  #000000;
#         }</style><table id="T_f822a_" ><thead>    <tr>        <th class="index_name level0" >Symbols</th>        <th class="col_heading level0 col0" >AAPL</th>        <th class="col_heading level0 col1" >MSFT</th>        <th class="col_heading level0 col2" >AMZN</th>        <th class="col_heading level0 col3" >GOOGL</th>        <th class="col_heading level0 col4" >FB</th>        <th class="col_heading level0 col5" >TSLA</th>        <th class="col_heading level0 col6" >V</th>    </tr>    <tr>        <th class="index_name level0" >Symbols</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f822a_level0_row0" class="row_heading level0 row0" >AAPL</th>
#                         <td id="T_f822a_row0_col0" class="data row0 col0" >0.000424</td>
#                         <td id="T_f822a_row0_col1" class="data row0 col1" >0.000300</td>
#                         <td id="T_f822a_row0_col2" class="data row0 col2" >0.000290</td>
#                         <td id="T_f822a_row0_col3" class="data row0 col3" >0.000273</td>
#                         <td id="T_f822a_row0_col4" class="data row0 col4" >0.000473</td>
#                         <td id="T_f822a_row0_col5" class="data row0 col5" >0.000383</td>
#                         <td id="T_f822a_row0_col6" class="data row0 col6" >0.000234</td>
#             </tr>
#             <tr>
#                         <th id="T_f822a_level0_row1" class="row_heading level0 row1" >MSFT</th>
#                         <td id="T_f822a_row1_col0" class="data row1 col0" >0.000300</td>
#                         <td id="T_f822a_row1_col1" class="data row1 col1" >0.000366</td>
#                         <td id="T_f822a_row1_col2" class="data row1 col2" >0.000299</td>
#                         <td id="T_f822a_row1_col3" class="data row1 col3" >0.000294</td>
#                         <td id="T_f822a_row1_col4" class="data row1 col4" >0.000490</td>
#                         <td id="T_f822a_row1_col5" class="data row1 col5" >0.000353</td>
#                         <td id="T_f822a_row1_col6" class="data row1 col6" >0.000243</td>
#             </tr>
#             <tr>
#                         <th id="T_f822a_level0_row2" class="row_heading level0 row2" >AMZN</th>
#                         <td id="T_f822a_row2_col0" class="data row2 col0" >0.000290</td>
#                         <td id="T_f822a_row2_col1" class="data row2 col1" >0.000299</td>
#                         <td id="T_f822a_row2_col2" class="data row2 col2" >0.000488</td>
#                         <td id="T_f822a_row2_col3" class="data row2 col3" >0.000285</td>
#                         <td id="T_f822a_row2_col4" class="data row2 col4" >0.000697</td>
#                         <td id="T_f822a_row2_col5" class="data row2 col5" >0.000374</td>
#                         <td id="T_f822a_row2_col6" class="data row2 col6" >0.000199</td>
#             </tr>
#             <tr>
#                         <th id="T_f822a_level0_row3" class="row_heading level0 row3" >GOOGL</th>
#                         <td id="T_f822a_row3_col0" class="data row3 col0" >0.000273</td>
#                         <td id="T_f822a_row3_col1" class="data row3 col1" >0.000294</td>
#                         <td id="T_f822a_row3_col2" class="data row3 col2" >0.000285</td>
#                         <td id="T_f822a_row3_col3" class="data row3 col3" >0.000369</td>
#                         <td id="T_f822a_row3_col4" class="data row3 col4" >0.000587</td>
#                         <td id="T_f822a_row3_col5" class="data row3 col5" >0.000315</td>
#                         <td id="T_f822a_row3_col6" class="data row3 col6" >0.000226</td>
#             </tr>
#             <tr>
#                         <th id="T_f822a_level0_row4" class="row_heading level0 row4" >FB</th>
#                         <td id="T_f822a_row4_col0" class="data row4 col0" >0.000473</td>
#                         <td id="T_f822a_row4_col1" class="data row4 col1" >0.000490</td>
#                         <td id="T_f822a_row4_col2" class="data row4 col2" >0.000697</td>
#                         <td id="T_f822a_row4_col3" class="data row4 col3" >0.000587</td>

# %%
nrosActivos = len(rendimiento.columns)
nrosActivos
# Out:
# 7

# %% [markdown]
# ##### Definimos 3 arrays.
#     - PesosPortafolio = pesos randoms con cantidad de elementos igual al numero de activos.
#     - rportafolio = Rendimiento del portafolio
#     - sdPortafolio = desvio standard, o riesgo del portafolio

# %%
pesosPortafolio = []
rportafolio = []
sdPortafolio = []

# %% [markdown]
# ##### Generamos una matriz de size 7, y le asignamos valor random. Luego dividimos array por su valor de suma para que toda la suma del array sea = 1
#     - El range define la cantidad de muestras aleatorias que vamos a hacer en la simulacion

# %%
for x in range(50000):
    pesos = np.random.random(nrosActivos) # Matriz de 1x7
    pesos /= np.sum(pesos) 
    pesosPortafolio.append(pesos) 
    # Retorno la "sumaProducto" o el producto de la matriz 
    # con los porcentajes de inversion X el rendimiento de cada activo
    rportafolio.append(np.dot(rendimiento.mean(), pesos)) # rendimiento.mean() = matriz de 7X1
    # np.dot(mCovarianzas, pesos)  retorna matriz 1X7 de multiplicar los
    # pesos(porcentaje a invertir) y la matriz de covarianzas
    # A esa matriz de 1X7 de varianzas, la vuelvo a multiplicar por pesos.T
    # eso nos devuelve un solo resultado, la varianza de la inversion y
    # posteriormente el STD
    sdPortafolio.append(np.sqrt(
        np.dot(pesos.T, np.dot(mCovarianzas, pesos))
    ))

# %% [markdown]
# #### EJEMPLO
# ##### Para la primera distribucion de los dolares (%) en los 7 activos:

# %%
for i in range(len(pesosPortafolio[0])):
    print(rendimiento.columns[i],' -> ', round(pesosPortafolio[0][i]*100,2), '%')
# Out:
# AAPL  ->  1.78 %
# MSFT  ->  25.0 %
# AMZN  ->  5.9 %
# GOOGL  ->  23.24 %
# FB  ->  11.77 %
# TSLA  ->  21.17 %
# V  ->  11.13 %

# %% [markdown]
#  ##### Tiene el siguiente rendimiento (%):

# %%
str(round(rportafolio[0] * 100,2)) + '%'
# Out:
# '0.07%'

# %% [markdown]
#  ##### Tiene el siguiente riesgo (%):

# %%
str(round(sdPortafolio[0] * 100,2)) + '%'
# Out:
# '2.08%'

# %% [markdown]
# ##### A partir de estas 3 variables, vamos a buscar minimizar el riesgo y maximizar el retorno
#     -Generamos un diccionario de listas -> lista de rendimiento, riesgo y una lista para cada accion con sus porcentajes de inversion

# %%
diccionario = {'Rendimiento': rportafolio, "Riesgo": sdPortafolio}
for i, accion in enumerate(rendimiento.columns.tolist()):
    diccionario['USD '+ accion] = [w[i] for w in pesosPortafolio]

# %% [markdown]
# #####  Generamos un DataFrame para tener las inversiones, riesgo y rendimiento en una sola linea

# %%
matrizPortafolio = pd.DataFrame(diccionario)
matrizPortafolio
# Out:
#        Rendimiento    Riesgo  USD AAPL  USD MSFT  USD AMZN  USD GOOGL  \
# 0         0.000700  0.020846  0.017809  0.250027  0.059046   0.232391
# 1         0.000577  0.022544  0.172087  0.127277  0.027993   0.188963
# 2        -0.000508  0.021998  0.118214  0.090704  0.109048   0.219503
# 3         0.001058  0.019028  0.237144  0.140964  0.225030   0.086352
# 4         0.000355  0.020138  0.140893  0.177239  0.158447   0.172006
# ...            ...       ...       ...       ...       ...        ...
# 49995     0.000368  0.019191  0.072418  0.064724  0.159620   0.261274
# 49996     0.000217  0.021785  0.156942  0.107140  0.006437   0.093564
# 49997     0.001364  0.020282  0.273524  0.015232  0.004455   0.221585
# 49998     0.000116  0.022425  0.034133  0.141123  0.188690   0.077076
# 49999     0.000243  0.021514  0.189169  0.107633  0.160059   0.143108
#
#          USD FB  USD TSLA     USD V
# 0      0.117718  0.211687  0.111321
# 1      0.171637  0.255991  0.056052
# 2      0.294237  0.003143  0.165152
# 3      0.037708  0.145458  0.127344
# 4      0.154457  0.087863  0.109094
# ...         ...       ...       ...
# 49995  0.127616  0.075759  0.238590
# 49996  0.220077  0.194826  0.221014
# 49997  0.011583  0.272178  0.201443
# 49998  0.228349  0.183194  0.147434
# 49999  0.197494  0.133281  0.069256
#
# [50000 rows x 9 columns]

# %% [markdown]
# #### Frontera eficiente

# %%
plt.figure(figsize=(13,9))
sns.scatterplot(data=matrizPortafolio, x = 'Riesgo', y='Rendimiento', s=30)
plt.show()

# %%
minimaVarianza = matrizPortafolio.iloc[matrizPortafolio['Riesgo'].idxmin()]
minimaVarianza
# Out:
# Rendimiento    0.000837
# Riesgo         0.016731
# USD AAPL       0.141948
# USD MSFT       0.021061
# USD AMZN       0.137498
# USD GOOGL      0.364264
# USD FB         0.000741
# USD TSLA       0.000748
# USD V          0.333739
# Name: 10408, dtype: float64

# %%
matrizPortafolio.plot(x='Riesgo',y='Rendimiento', kind='scatter', figsize=(13,9) )
plt.scatter(x=minimaVarianza[1], y=minimaVarianza[0], color='red', marker='*', s=300)

# %% [markdown]
# #### Portafolio optimo
#     - Tomamos la taza libre de riesgo a la fecha: 18/10/2022 -> 4%. La dividimos por 12 meses
# ##### E(Rp) - RF / Desv(Rp)
#     - al rendimiento le restamos el RF y dividimos por su Riesgo. El maximo valor que nos devuelva va a ser el portafolio optimo

# %%
rf = 0.04 / 12

# %%
optimo = matrizPortafolio.iloc[((matrizPortafolio['Rendimiento'] - rf) / matrizPortafolio['Riesgo']).idxmax()]
optimo
# Out:
# Rendimiento    0.001767
# Riesgo         0.027414
# USD AAPL       0.022019
# USD MSFT       0.064611
# USD AMZN       0.187310
# USD GOOGL      0.148174
# USD FB         0.015624
# USD TSLA       0.556082
# USD V          0.006180
# Name: 14954, dtype: float64

# %%
matrizPortafolio.plot(x='Riesgo',y='Rendimiento', kind='scatter', figsize=(13,9) )
plt.scatter(x=minimaVarianza[1], y=minimaVarianza[0], color='red', marker='*', s=300)
plt.scatter(x=optimo[1], y=optimo[0], color='green', marker='*', s=300)
plt.savefig('FronteraEficiente', dpi=200)
